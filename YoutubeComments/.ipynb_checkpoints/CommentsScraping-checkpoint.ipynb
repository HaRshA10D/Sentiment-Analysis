# %%
import json
import sys
import re

from urllib import *

from urllib.parse import urlparse, urlencode, parse_qs
from urllib.request import  urlopen

import nltk
from textblob import TextBlob
import numpy as np

YOUTUBE_COMMENT_URL = 'https://www.googleapis.com/youtube/v3/commentThreads'

# %%
parms = {
    'part': 'snippet,replies',
    'maxResults': '100',
    'videoId': 'j5-yKhDd64s',
    'textFormat': 'plainText',
    'key': 'AIzaSyDR5uohfVy7tRxZrE71r6_khZX3P18IC-U'
}

num_pages = 25

# %%
def openURL(url, parms):
    f = urlopen(url + '?' + urlencode(parms))
    data = f.read()
    f.close()
    matches = data.decode("utf-8")
    return matches

# %%
words = set(nltk.corpus.words.words())
i = 1
all_comments = []
all_replies = []

for x in range(num_pages):
    
    matches = openURL(YOUTUBE_COMMENT_URL, parms)
    mat = json.loads(matches)

    nextPageToken = mat.get("nextPageToken")
    parms.update({'pageToken': nextPageToken})
    
    for item in mat['items']:

        comment_data = item['snippet']['topLevelComment']
        commentor = comment_data['snippet']['authorDisplayName']
        comment = comment_data['snippet']['textDisplay']

        comment = " ".join(re.findall("[a-zA-Z]+", comment))
        comment = " ".join(w for w in nltk.wordpunct_tokenize(comment) if w.lower() in words or not w.isalpha())
        
        if len(comment) > 20:
            all_comments.append(comment)
            #print('Number: %d'%i)
            #print("Comment by {}:\n{}".format(commentor, comment))
            i += 1

            j = 1
            if 'replies' in item.keys():
                replies = []

                for reply in item['replies']['comments']:

                    rauthor = reply['snippet']['authorDisplayName']
                    rtext = reply["snippet"]["textDisplay"]

                    rtext = " ".join(re.findall("[a-zA-Z]+", rtext))
                    rtext = " ".join(w for w in nltk.wordpunct_tokenize(rtext) if w.lower() in words or not w.isalpha())

                    replies.append(rtext)
                    #print("\tReply no: {} ; by {}: {}".format(j,rauthor, rtext))
                    j += 1

                if len(replies) == 0: replies =[' ']
                all_replies.append(replies)

# %%
import pandas as pd
df = pd.DataFrame(data = all_comments, columns = ['Comment'])
df.to_csv('comments.csv',index=False,header=False)
df
# Out:
#                                                Comment
# 0                             he made this when he was
# 1                who s watching this on the th of June
# 2    is the most spectacular beautiful wonderful gl...
# 3    might be saying right now Why the did I volunt...
# 4    What the is this ass video IT S TRASH also lik...
# 5    oh baby baby oh baby like baby no baby baby ba...
# 6                           I love you my name is from
# 7                            who s watching this today
# 8        es tan lindo tu lo yo soy y fan de ti mi amor
# 9                          How old is he In this video
# 10   lo n baby el era un ni o ni lo no me en lo q s...
# 11                 this should be his who came for the
# 12                        Great music to scare Trump p
# 13   this is the first song I I was addicted to him...
# 14                        million subscriber can i get
# 15             Who came to switch from dislike to like
# 16                      I get many but not his heart v
# 17                     AI E TAO LINDO SE NO CANAL JUST
# 18                    can i get like please my cat Die
# 19   Some are afraid of under their well I m afraid...
# 20                          I love you Love and pretty
# 21         Why does it have to many this song is great
# 22       my a video of me singing this song when i was
# 23                 I LOVE THIS SONG Na I was This song
# 24                              Let s kill ourselves D
# 25   Now I don t want to go bowling now because of ...
# 26   Dude should really consider taking this video ...
# 27         Who else came here because of Like if u did
# 28        I love this dude so much i put my in his ass
# 29   Someone that t like the video Come on let s al...
# ..                                                 ...
# 830  All my fellow million from can each of us like...
# 831                             there is way more than
# 832                             Hi push S World record
# 833                            why the are higher than
# 834           who came here just to dislike this video
# 835  I first to this when I was and now am who is w...
# 836     Why am I watching this piece of sh t s old hit
# 837                           THIS SONG IS SO ANNOYING
# 838                             Mil WE BEAT THE RECORD
# 839                            here to see how many it
# 840  i hate myself for saying this but i actually l...
# 841                             DRAKE IS IN THIS VIDEO
# 842             Who came from top most and who this is
# 843                             super song of all time
# 844  someone text me and said I was a gay I am a gi...
# 845  I remember this being my favorite song in the ...
# 846                who s here to look at the about the
# 847                      who s here to not look at the
# 848                      who s here to not look at the
# 849                   who is in in June like if you do
# 850                  later people still hate this song
# 851                 I m just here to dislike the video
# 852               kill every th like is pistol shot on
# 853  Never forget he s not a he sang dis when if wa...
# 854  why is everyone so jealous over his success he...
# 855                             Who s watching this in
# 856                     Who s is watching this in June
# 857                            hate this song but Baby
# 858                  who is cancer while watching this
# 859               actually why we it so much back then
#
# [860 rows x 1 columns]

# %%
i = 1
x_points = []
y_points = []

nz = 0
all_senti = 0.0
for comment in all_comments:
    lines = comment.split('.')
    polarity = 0.0
    x = 0
    for line in lines:
        tb = TextBlob(line)
        line_pol = tb.sentiment.polarity
        polarity += line_pol
        if(line_pol!=0.0) : x += 1
    if x == 0: total_senti = 0.0 
    else: total_senti = polarity/float(x)
    all_senti += total_senti 
    x_points.append(i)
    y_points.append(total_senti)
    #print('polarity of review no: %d = %f'%(i,total_senti))
    i += 1
    if total_senti != 0.0: nz += 1
        
all_senti = all_senti/float(nz)
print(i)
    
y = np.tile(all_senti,(i-1,1))
    
import matplotlib.pyplot as plt
plt.plot(x_points,y_points)
plt.plot(x_points,y)
plt.xlabel('Comment')
plt.ylabel('Polarity')
plt.savefig('comments')
plt.show()
# Out:
# 861
