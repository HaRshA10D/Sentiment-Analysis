# %%
import json
import sys
import re

from urllib import *

from urllib.parse import urlparse, urlencode, parse_qs
from urllib.request import  urlopen

import nltk
from textblob import TextBlob
import numpy as np

YOUTUBE_COMMENT_URL = 'https://www.googleapis.com/youtube/v3/commentThreads'

# %%
parms = {
    'part': 'snippet,replies',
    'maxResults': '100',
    'videoId': 'J5Z5o09yvO4',
    'textFormat': 'plainText',
    'key': 'AIzaSyDR5uohfVy7tRxZrE71r6_khZX3P18IC-U'
}

num_pages = 1

# %%
def openURL(url, parms):
    f = urlopen(url + '?' + urlencode(parms))
    print(url + '?' + urlencode(parms))
    data = f.read()
    f.close()
    matches = data.decode("utf-8")
    return matches

# %%
words = set(nltk.corpus.words.words())
i = 1
all_comments = []
all_replies = []

for x in range(num_pages):
    
    matches = openURL(YOUTUBE_COMMENT_URL, parms)
    mat = json.loads(matches)

    nextPageToken = mat.get("nextPageToken")
    parms.update({'pageToken': nextPageToken})
    
    for item in mat['items']:

        comment_data = item['snippet']['topLevelComment']
        commentor = comment_data['snippet']['authorDisplayName']
        comment = comment_data['snippet']['textDisplay']

        comment = " ".join(re.findall("[a-zA-Z]+", comment))
        comment = " ".join(w for w in nltk.wordpunct_tokenize(comment) if w.lower() in words or not w.isalpha())
        
        if len(comment) > 20:
            all_comments.append(comment)
            #print('Number: %d'%i)
            #print("Comment by {}:\n{}".format(commentor, comment))
            i += 1

            j = 1
            if 'replies' in item.keys():
                replies = []

                for reply in item['replies']['comments']:

                    rauthor = reply['snippet']['authorDisplayName']
                    rtext = reply["snippet"]["textDisplay"]

                    rtext = " ".join(re.findall("[a-zA-Z]+", rtext))
                    rtext = " ".join(w for w in nltk.wordpunct_tokenize(rtext) if w.lower() in words or not w.isalpha())

                    replies.append(rtext)
                    #print("\tReply no: {} ; by {}: {}".format(j,rauthor, rtext))
                    j += 1

                if len(replies) == 0: replies =[' ']
                all_replies.append(replies)

# %%
import pandas as pd
df = pd.DataFrame(data = all_comments, columns = ['Comment'])
df.to_csv('comments.csv',index=False,header=False)
df
# Out:
#                                               Comment
# 0      There is some in this world worth fighting for
# 1   Trump just put the bigger dick policy theory t...
# 2   the Carlin some good and we definitely have a ...
# 3   they did bomb white country as far as i know mine
# 4   Think beyond the cheap to see what this very f...
# 5                               we out like what with
# 6   I think he s off base about U S And being a do...
# 7   War can be properly defined as an outward mani...
# 8                    Watch a Documentary Why we fight
# 9   CAN SOMEONE PLEASE tell me the name of that en...
# 10                  Comic genius may he rest in peace
# 11  it but at some point a certain group would tel...
# 12                       Why does this sound familiar
# 13                             Garrison in South Park
# 14  As the saying goes if you don t like this war ...
# 15                       to all group s Veteran s I m
# 16            the were white and bombed them in the s
# 17  You ignorant are all wrong If it were not for ...
# 18                   Bush Dick and Colin did it twice
# 19  That guy was incredible Telling loud and clear...
# 20            anyone else of garrison from south park
# 21                              I can t get enough of
# 22                  Carlin was way ahead of the times
# 23  white people bombed by the US air force with U...
# 24       From show is this From that show in new york
# 25  did bomb white people In In Just because the h...
# 26            The best of stand up I ever seen Genius
# 27          this man his business R I P God bless you
# 28  I am an and I thought this was funny as And pa...
# 29          Too bad t live long enough to make fun of
# ..                                                ...
# 35                            a lot of the he were by
# 36  The cautionary note may contain coarse languag...
# 37                          it s true look like giant
# 38  I don t know why are laughing they should be c...
# 39                  Tried to subscribe t but I anyway
# 40              extremely funny but pure wisdom sadly
# 41  Man he is so insightful damn Why oh why we don...
# 42  Well got out By the Trump They double check wh...
# 43                want war to stop eliminate with war
# 44                      White people what bombed Yeah
# 45            what s wrong with the name colin though
# 46            we need Carlin were so RIP with out him
# 47                    what would Carlin made of trump
# 48                           I lost it at em to death
# 49                          most roll over on command
# 50  was probably one of the very few i truly like ...
# 51  This is guy might not be funny but he some sen...
# 52  Come on War because over compensation is insan...
# 53                the last point was super insightful
# 54  War is no longer about one s country It s abou...
# 55  This guy was Pure Genius I m surprise the Gove...
# 56  He left out white people in the who were bombe...
# 57  a friend of mine made a good point if we the w...
# 58  it s funny because he a point But I lost frien...
# 59  we only fight the want and tell us to fight be...
# 60  Every gun that is made every warship every roc...
# 61  wut do u think about police n military I think...
# 62  man I wish you was still around he would have ...
# 63  Glorification of war is a disease in War war s...
# 64                        I still miss he was the man
#
# [65 rows x 1 columns]

# %%
i = 1
x_points = []
y_points = []

nz = 0
all_senti = 0.0
for comment in all_comments:
    lines = comment.split('.')
    polarity = 0.0
    x = 0
    for line in lines:
        tb = TextBlob(line)
        line_pol = tb.sentiment.polarity
        polarity += line_pol
        if(line_pol!=0.0) : x += 1
    if x == 0: total_senti = 0.0 
    else: total_senti = polarity/float(x)
    all_senti += total_senti 
    x_points.append(i)
    y_points.append(total_senti)
    #print('polarity of review no: %d = %f'%(i,total_senti))
    i += 1
    if total_senti != 0.0: nz += 1
        
all_senti = all_senti/float(nz)
print(nz)
    
y = np.tile(all_senti,(i-1,1))
    
import matplotlib.pyplot as plt
plt.plot(x_points,y_points)
plt.plot(x_points,y)
plt.xlabel('Comment')
plt.ylabel('Polarity')
plt.savefig('comments')
plt.show()
# Out:
# 41

# %%
df.head()
# Out:
#                                              Comment
# 0     There is some in this world worth fighting for
# 1  Trump just put the bigger dick policy theory t...
# 2  the Carlin some good and we definitely have a ...
# 3  they did bomb white country as far as i know mine
# 4  Think beyond the cheap to see what this very f...

# %%
YOUTUBE_COMMENT_URL + '?' + urlencode(parms)
# Out:
# 'https://www.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&maxResults=100&videoId=J5Z5o09yvO4&textFormat=plainText&key=AIzaSyDR5uohfVy7tRxZrE71r6_khZX3P18IC-U&pageToken=None'
